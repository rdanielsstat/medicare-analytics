# %% [markdown]
# Make sure the data have been previously loaded and the postgre database is up and running.
#
# ```bash
# docker compose up -d postgres
# ```

# %%
from sqlalchemy import create_engine
import pandas as pd
from pathlib import Path
from dotenv import load_dotenv
import os
import importlib.metadata

print("sqlalchemy version: "+ str(importlib.metadata.version("SQLAlchemy")))
print("pandas version: " + str(pd.__version__))
print("dotenv version: " + str(importlib.metadata.version("python-dotenv")))
# Out:
# sqlalchemy version: 2.0.47
# pandas version: 3.0.1
# dotenv version: 1.2.1

# %%
# Load .env file
env_path = Path('.') / '.env'
load_dotenv(dotenv_path=env_path)

POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")
POSTGRES_DB = os.getenv("POSTGRES_DB")
POSTGRES_PORT = os.getenv("POSTGRES_PORT", 5432)  # default to 5432

engine = create_engine(
    f"postgresql+psycopg2://{POSTGRES_USER}:{POSTGRES_PASSWORD}@localhost:{POSTGRES_PORT}/{POSTGRES_DB}"
)

# %%
# Test a query
df = pd.read_sql("SELECT * FROM public.medicare_monthly_enrollment LIMIT 10;", engine)
df.head()
# Out:
#    year month bene_geo_lvl bene_state_abrvtn bene_state_desc bene_county_desc  \
# 0  2013  Year     National                US        National            Total
# 1  2013  Year        State                AL         Alabama            Total
# 2  2013  Year       County                AL         Alabama   Autauga County
# 3  2013  Year       County                AL         Alabama   Baldwin County
# 4  2013  Year       County                AL         Alabama   Barbour County
#
#   bene_fips_cd   tot_benes  orgnl_mdcr_benes  ma_and_oth_benes  ...  \
# 0               52425659.0        37613096.0        14812563.0  ...
# 1           01    921477.0          711448.0          210029.0  ...
# 2        01001      9323.0            6484.0            2840.0  ...
# 3        01003     41033.0           28775.0           12258.0  ...
# 4        01005      5847.0            5036.0             810.0  ...
#
#    b_tot_benes  b_orgnl_mdcr_benes  b_ma_and_oth_benes  \
# ...
